# %%
a = 7153109017
b = "nam"
c = "Kinh Tế Số"
d = " Nguyễn Tiến Dũng "
year = 19
g = float(input("điểm toán="))
h = float(input("điểm lý="))
j = float(input("điểm hóa="))
print("MSV:", a)
print("giới tính:", b)
print("khoa:", c)
print("họ và tên:", d)
print("tuổi:", year)
print("điểm trung bình = %.2f" % ((g+h+j)/3))
# Out:
# điểm toán= 8.8
# điểm lý= 8
# điểm hóa= 8.5
# MSV: 7153109017
# giới tính: nam
# khoa: Kinh Tế Số
# họ và tên:  Nguyễn Tiến Dũng
# tuổi: 19
# điểm trung bình = 8.43
